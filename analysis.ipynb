# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchtext.datasets import WikiText2
import pandas as pd
from nltk.corpus import brown
import numpy as np
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import sys
from sklearn.manifold import TSNE
import plotly.graph_objects as go
import os

# %% [markdown]
# ## Analyze

# %%
from net import Net_CBOW

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
epoch_n = 5
version = "april30_WT2_nodatalim_20epoch_64dim_100minf_4window_epoch"
net = torch.load(f"saves/apr30epochs/model_{version}{epoch_n}.pt", map_location=device)
vocab = torch.load(f"saves/vocab_april30_WT2_nodatalim_20epoch_64dim_50minf_2window.pt")
# Out:
# cpu

# %%
# get first layer of the model
embeddings = list(net.parameters())[0]
embeddings = embeddings.cpu().detach().numpy()

# normalize the embeddings layer
norms = (embeddings ** 2).sum(axis=1) ** (0.5)
norms = np.reshape(norms, (len(norms), 1))
embeddings_norm = embeddings / norms
embeddings_norm.shape
embeddings_df = pd.DataFrame(embeddings)

# t-SNE transform
tsne = TSNE(n_components=2)
embeddings_df_tsne = tsne.fit_transform(embeddings_df)
embeddings_df_tsne = pd.DataFrame(embeddings_df_tsne)

embeddings_df_tsne.index = vocab.keys()

# %%
numeric = embeddings_df_tsne.index.str.isnumeric()
color = np.where(numeric, "green", "black")
fig = go.Figure()

fig.add_trace(
    go.Scatter(
        x=embeddings_df_tsne[0],
        y=embeddings_df_tsne[1],
        mode="text",
        text=embeddings_df_tsne.index,
        textposition="middle center",
        textfont=dict(color=color),
    )
)
# fig.write_html("word2vec_visualization.html")
fig

# %%
def lookup_id(word, vocab=vocab):
    if word not in vocab:
        return vocab["<unk>"]
    return vocab[word]
def lookup_token(word_id, vocab=vocab):
    for word in vocab:
        if vocab[word] == word_id:
            return word
    return None
def get_top_similar(word: str, topN: int = 10):
    if word not in vocab:
        print("Out of vocabulary word")
        return
    word_id = lookup_id(word)

    word_vec = embeddings_norm[word_id]
    word_vec = np.reshape(word_vec, (len(word_vec), 1))
    dists = np.matmul(embeddings_norm, word_vec).flatten()
    topN_ids = np.argsort(-dists)[1 : topN + 1]

    topN_dict = {}
    for sim_word_id in topN_ids:
        # sim_word = vocab.lookup_token(sim_word_id)
        sim_word = "<unk_>"
        for k in vocab:
            if vocab[k] == sim_word_id:
                sim_word = k
                break
        topN_dict[sim_word] = dists[sim_word_id]
    return topN_dict

# %%
for word, sim in get_top_similar("shelter").items():
    print("{}: {:.3f}".format(word, sim))
# Out:
# cars: 0.240
# schools: 0.210
# position: 0.204
# damage: 0.199
# sequences: 0.197
# markets: 0.186
# island: 0.180
# rates: 0.180
# fans: 0.177
# education: 0.175

# %%
emb1 = embeddings[vocab["things"]]
emb2 = embeddings[vocab["thing"]]
emb3 = embeddings[vocab["woman"]]

emb4 = emb1 - emb2 + emb3
emb4_norm = (emb4 ** 2).sum() ** (1 / 2)
emb4 = emb4 / emb4_norm

emb4 = np.reshape(emb4, (len(emb4), 1))
dists = np.matmul(embeddings_norm, emb4).flatten()

top5 = np.argsort(-dists)[:5]

for word_id in top5:
    print("{}: {:.3f}".format(lookup_token(word_id), dists[word_id]))
# Out:
# woman: 0.637
# things: 0.497
# players: 0.241
# team: 0.212
# people: 0.195

# %%
folder = "train_data/"
version1 = "_data_"
version2 = "_wt2_window4.pt"

# %%
x_test = torch.load(f"{folder}test{version1}x{version2}")
y_test = torch.load(f"{folder}test{version1}y{version2}")

# %%
x_test[0]
# Out:
# [629, 4, 22, 29, 108, 1, 392, 5]

# %%
lookup_token(y_test[1])
# Out:
# 'film'

# %%
[lookup_token(i) for i in x_test[3]]
# Out:
# ['an', 'english', 'film', ',', 'and', 'theatre', 'actor', '.']

# %%
vocab = torch.load("saves/vocab_may1_WT2_transformer_min25f.pt")
print(len(vocab))
def lookup_id(word, vocab=vocab):
    if word not in vocab:
        return vocab["<unk>"]
    return vocab[word]
def lookup_token(word_id, vocab=vocab):
    for word in vocab:
        if vocab[word] == word_id:
            return word
    return "<unk>"
# Out:
# 6908

# %%
from datasets import load_dataset
wikitext2 = load_dataset("wikitext", "wikitext-2-v1")
# text_train = wikitext2["train"]['text']
# text_train = [item.lower().strip() for item in text_train if len(item) > 0]
text_test = wikitext2["test"]['text']
text_test = [item.lower().strip() for item in text_test if len(item) > 0]
len(text_test)
# text_train = [item.split(" ") + ["\n"] for item in text_train if "=" not in item]
text_test = [item.split(" ") + ["\n"] for item in text_test if "=" not in item]

seq_length = 128
buffer = 20

x_test = [[lookup_id(word) for word in paragraph[len(paragraph)-seq_length-1:len(paragraph)-1]] for paragraph in text_test if len(paragraph) >= seq_length + buffer+1]

trytest = [lookup_token(i) for i in x_test[-1]]

# %%
from transformer import TransformerModel

# %%
# transformer = torch.load("saves/model_transformer_apr29_1130pm.pt")
# transformer = torch.load("saves/model_transformer_may1_1250pm.pt")
transformer = torch.load("saves/model_transformer_may3_1200am.pt")
vocab = torch.load(f"saves/vocab_may1_WT2_transformer_min25f.pt")

# %%
def embed(word):    
    return transformer.input_emb(torch.tensor(lookup_id(word)))
cos = nn.CosineSimilarity(dim=0, eps=1e-6)
len(embed("mother"))
# Out:
# 512

# %%
device = torch.device("cpu")
ntokens = len(vocab)
input = torch.randint(ntokens, (1, 1), dtype=torch.long).to(device)
model = transformer
temperature = 2
log_interval = 1

input = 'he claimed in an interview that '
# input = ['<unk>', 'claimed', 'in', 'an', 'interview', 'at', 'the', 'time', 'of', 'the', 'film', "'s", 'release', 'that', 'the', 'character', 'of', 'minnesota', '<unk>', 'was', 'based', 'on', '<unk>', ',', 'who', 'at', 'the', 'time', 'was', 'known', 'as', '"', 'new', 'york', '<unk>', '"', '.', '<unk>', 'immediately', 'adopted', 'the', 'minnesota', '<unk>', '<unk>', 'and', '<unk>', 'his', 'association', 'with', 'the', 'film', 'into', 'book', 'and', 'television', '<unk>', 'and', 'other', '<unk>', '.', 'author', 'walter', '<unk>', 'denied', 'for', 'the', 'rest', 'of', 'his', 'life', 'that', '<unk>', 'had', 'played', 'any', 'role', 'in', 'the', 'creation', 'of', 'the', 'character', '.', 'other', 'players', 'would', 'claim', ',', 'with', 'greater', 'or', '<unk>', 'degrees', 'of', '<unk>', ',', 'to', 'have', 'served', 'as']
input = [lookup_id(i) for i in input.strip().split(" ")]
# input = [lookup_id(i) for i in input]


print(input)
input = torch.tensor(input).view(len(input), 1)


with open('out_generation.txt', 'w') as outf:
    with torch.no_grad():  # no tracking history
        for i in range(20):
            print(i)
            output = model(input, False)
            word_weights = output[-1].squeeze().div(temperature).exp().cpu()
            word_idx = torch.multinomial(word_weights, 1)[0]
            word_tensor = torch.Tensor([[word_idx]]).long().to(device)
            print(word_tensor)
            input = torch.cat([input, word_tensor], 0)

            word = lookup_token(word_idx)

            outf.write(word + ('\n' if i % 20 == 19 else ' '))

            if i % log_interval == 0:
                print('| Generated {}/{} words'.format(i, [lookup_token(i[0])for i in input]))
# Out:
# [27, 760, 6, 29, 1128, 15]
# 0
# tensor([[2479]])
# | Generated 0/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys'] words
# 1
# tensor([[1978]])
# | Generated 1/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding'] words
# 2
# tensor([[6624]])
# | Generated 2/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests'] words
# 3
# tensor([[634]])
# | Generated 3/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european'] words
# 4
# tensor([[2138]])
# | Generated 4/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships'] words
# 5
# tensor([[309]])
# | Generated 5/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history'] words
# 6
# tensor([[5767]])
# | Generated 6/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed'] words
# 7
# tensor([[5780]])
# | Generated 7/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers'] words
# 8
# tensor([[1197]])
# | Generated 8/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily'] words
# 9
# tensor([[303]])
# | Generated 9/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved'] words
# 10
# tensor([[6138]])
# | Generated 10/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity'] words
# 11
# tensor([[2]])
# | Generated 11/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.'] words
# 12
# tensor([[5411]])
# | Generated 12/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman'] words
# 13
# tensor([[5563]])
# | Generated 13/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion'] words
# 14
# tensor([[4258]])
# | Generated 14/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree'] words
# 15
# tensor([[26]])
# | Generated 15/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his'] words
# 16
# tensor([[3729]])
# | Generated 16/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences'] words
# 17
# tensor([[15]])
# | Generated 17/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that'] words
# 18
# tensor([[99]])
# | Generated 18/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both'] words
# 19
# tensor([[671]])
# | Generated 19/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially'] words
# 20
# tensor([[943]])
# | Generated 20/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown'] words
# 21
# tensor([[3435]])
# | Generated 21/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled'] words
# 22
# tensor([[1981]])
# | Generated 22/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy'] words
# 23
# tensor([[130]])
# | Generated 23/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under'] words
# 24
# tensor([[1551]])
# | Generated 24/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh'] words
# 25
# tensor([[108]])
# | Generated 25/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film'] words
# 26
# tensor([[1232]])
# | Generated 26/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think'] words
# 27
# tensor([[1359]])
# | Generated 27/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy'] words
# 28
# tensor([[1545]])
# | Generated 28/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge'] words
# 29
# tensor([[1]])
# | Generated 29/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ','] words
# 30
# tensor([[1222]])
# | Generated 30/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox'] words
# 31
# tensor([[1]])
# | Generated 31/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ','] words
# 32
# tensor([[95]])
# | Generated 32/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used'] words
# 33
# tensor([[47]])
# | Generated 33/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her'] words
# 34
# tensor([[2558]])
# | Generated 34/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear'] words
# 35
# tensor([[1572]])
# | Generated 35/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease'] words
# 36
# tensor([[5736]])
# | Generated 36/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising'] words
# 37
# tensor([[3102]])
# | Generated 37/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g'] words
# 38
# tensor([[21]])
# | Generated 38/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '('] words
# 39
# tensor([[4623]])
# | Generated 39/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh'] words
# 40
# tensor([[3457]])
# | Generated 40/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican'] words
# 41
# tensor([[2074]])
# | Generated 41/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes'] words
# 42
# tensor([[986]])
# | Generated 42/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut'] words
# 43
# tensor([[3152]])
# | Generated 43/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean'] words
# 44
# tensor([[451]])
# | Generated 44/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock'] words
# 45
# tensor([[3887]])
# | Generated 45/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands'] words
# 46
# tensor([[5561]])
# | Generated 46/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns'] words
# 47
# tensor([[2586]])
# | Generated 47/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic'] words
# 48
# tensor([[144]])
# | Generated 48/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end'] words
# 49
# tensor([[2603]])
# | Generated 49/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing'] words
# 50
# tensor([[1240]])
# | Generated 50/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense'] words
# 51
# tensor([[576]])
# | Generated 51/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft'] words
# 52
# tensor([[609]])
# | Generated 52/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon'] words
# 53
# tensor([[1636]])
# | Generated 53/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended'] words
# 54
# tensor([[867]])
# | Generated 54/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward'] words
# 55
# tensor([[201]])
# | Generated 55/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now'] words
# 56
# tensor([[641]])
# | Generated 56/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non'] words
# 57
# tensor([[1884]])
# | Generated 57/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired'] words
# 58
# tensor([[8]])
# | Generated 58/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a'] words
# 59
# tensor([[6180]])
# | Generated 59/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds'] words
# 60
# tensor([[328]])
# | Generated 60/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written'] words
# 61
# tensor([[5190]])
# | Generated 61/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne'] words
# 62
# tensor([[2741]])
# | Generated 62/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa'] words
# 63
# tensor([[4104]])
# | Generated 63/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull'] words
# 64
# tensor([[36]])
# | Generated 64/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but'] words
# 65
# tensor([[609]])
# | Generated 65/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon'] words
# 66
# tensor([[4346]])
# | Generated 66/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest'] words
# 67
# tensor([[13]])
# | Generated 67/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on'] words
# 68
# tensor([[4731]])
# | Generated 68/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining'] words
# 69
# tensor([[480]])
# | Generated 69/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events'] words
# 70
# tensor([[6369]])
# | Generated 70/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved'] words
# 71
# tensor([[5777]])
# | Generated 71/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive'] words
# 72
# tensor([[3784]])
# | Generated 72/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback'] words
# 73
# tensor([[5320]])
# | Generated 73/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240'] words
# 74
# tensor([[2653]])
# | Generated 74/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting'] words
# 75
# tensor([[1132]])
# | Generated 75/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something'] words
# 76
# tensor([[2777]])
# | Generated 76/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate'] words
# 77
# tensor([[3320]])
# | Generated 77/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist'] words
# 78
# tensor([[10]])
# | Generated 78/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist', 'was'] words
# 79
# tensor([[5733]])
# | Generated 79/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist', 'was', 'examined'] words
# 80
# tensor([[855]])
# | Generated 80/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist', 'was', 'examined', 'woman'] words
# 81
# tensor([[1513]])
# | Generated 81/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist', 'was', 'examined', 'woman', 'remain'] words
# 82
# tensor([[151]])
# | Generated 82/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist', 'was', 'examined', 'woman', 'remain', 'american'] words
# 83
# tensor([[112]])
# | Generated 83/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist', 'was', 'examined', 'woman', 'remain', 'american', '5'] words
# 84
# tensor([[2334]])
# | Generated 84/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist', 'was', 'examined', 'woman', 'remain', 'american', '5', 'hip'] words
# 85
# tensor([[6002]])
# | Generated 85/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist', 'was', 'examined', 'woman', 'remain', 'american', '5', 'hip', 'egg'] words
# 86
# tensor([[4321]])
# | Generated 86/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist', 'was', 'examined', 'woman', 'remain', 'american', '5', 'hip', 'egg', 'struggled'] words
# 87
# tensor([[5310]])
# | Generated 87/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist', 'was', 'examined', 'woman', 'remain', 'american', '5', 'hip', 'egg', 'struggled', 'resident'] words
# 88
# tensor([[2100]])
# | Generated 88/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist', 'was', 'examined', 'woman', 'remain', 'american', '5', 'hip', 'egg', 'struggled', 'resident', 'simple'] words
# 89
# tensor([[2904]])
# | Generated 89/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist', 'was', 'examined', 'woman', 'remain', 'american', '5', 'hip', 'egg', 'struggled', 'resident', 'simple', 'carter'] words
# 90
# tensor([[3553]])
# | Generated 90/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist', 'was', 'examined', 'woman', 'remain', 'american', '5', 'hip', 'egg', 'struggled', 'resident', 'simple', 'carter', 'walk'] words
# 91
# tensor([[4075]])
# | Generated 91/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist', 'was', 'examined', 'woman', 'remain', 'american', '5', 'hip', 'egg', 'struggled', 'resident', 'simple', 'carter', 'walk', 'cool'] words
# 92
# tensor([[6048]])
# | Generated 92/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist', 'was', 'examined', 'woman', 'remain', 'american', '5', 'hip', 'egg', 'struggled', 'resident', 'simple', 'carter', 'walk', 'cool', 'filed'] words
# 93
# tensor([[2320]])
# | Generated 93/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist', 'was', 'examined', 'woman', 'remain', 'american', '5', 'hip', 'egg', 'struggled', 'resident', 'simple', 'carter', 'walk', 'cool', 'filed', 'jump'] words
# 94
# tensor([[1279]])
# | Generated 94/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist', 'was', 'examined', 'woman', 'remain', 'american', '5', 'hip', 'egg', 'struggled', 'resident', 'simple', 'carter', 'walk', 'cool', 'filed', 'jump', 'speed'] words
# 95
# tensor([[171]])
# | Generated 95/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist', 'was', 'examined', 'woman', 'remain', 'american', '5', 'hip', 'egg', 'struggled', 'resident', 'simple', 'carter', 'walk', 'cool', 'filed', 'jump', 'speed', 'back'] words
# 96
# tensor([[844]])
# | Generated 96/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist', 'was', 'examined', 'woman', 'remain', 'american', '5', 'hip', 'egg', 'struggled', 'resident', 'simple', 'carter', 'walk', 'cool', 'filed', 'jump', 'speed', 'back', 'shows'] words
# 97
# tensor([[8]])
# | Generated 97/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist', 'was', 'examined', 'woman', 'remain', 'american', '5', 'hip', 'egg', 'struggled', 'resident', 'simple', 'carter', 'walk', 'cool', 'filed', 'jump', 'speed', 'back', 'shows', 'a'] words
# 98
# tensor([[6174]])
# | Generated 98/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist', 'was', 'examined', 'woman', 'remain', 'american', '5', 'hip', 'egg', 'struggled', 'resident', 'simple', 'carter', 'walk', 'cool', 'filed', 'jump', 'speed', 'back', 'shows', 'a', 'reservoir'] words
# 99
# tensor([[733]])
# | Generated 99/['he', 'claimed', 'in', 'an', 'interview', 'that', 'boys', 'finding', 'nests', 'european', 'championships', 'history', 'addressed', 'battlecruisers', 'daily', 'moved', 'proximity', '.', 'bradman', 'mansion', 'agree', 'his', 'differences', 'that', 'both', 'initially', 'shown', 'entitled', 'italy', 'under', 'welsh', 'film', 'think', 'boy', 'ridge', ',', 'fox', ',', 'used', 'her', 'fear', 'disease', 'comprising', 'g', '(', 'flesh', 'mexican', 'athletes', 'cut', 'dean', 'rock', 'bands', 'campaigns', 'athletic', 'end', 'producing', 'defense', 'aircraft', 'soon', 'attended', 'forward', 'now', 'non', 'fired', 'a', 'bonds', 'written', 'airborne', 'fa', 'skull', 'but', 'soon', 'ernest', 'on', 'gaining', 'events', 'resolved', 'impressive', 'quarterback', '240', 'getting', 'something', 'gate', 'journalist', 'was', 'examined', 'woman', 'remain', 'american', '5', 'hip', 'egg', 'struggled', 'resident', 'simple', 'carter', 'walk', 'cool', 'filed', 'jump', 'speed', 'back', 'shows', 'a', 'reservoir', 'radio'] words

# %%
# get first layer of the model
embeddings = list(transformer.input_emb.parameters())[0]
embeddings = embeddings.cpu().detach().numpy()

# normalize the embeddings layer
norms = (embeddings ** 2).sum(axis=1) ** (0.5)
norms = np.reshape(norms, (len(norms), 1))
embeddings_norm = embeddings / norms
embeddings_norm.shape
embeddings_df = pd.DataFrame(embeddings)

# t-SNE transform
tsne = TSNE(n_components=2)
embeddings_df_tsne = tsne.fit_transform(embeddings_df)
embeddings_df_tsne = pd.DataFrame(embeddings_df_tsne)

embeddings_df_tsne.index = vocab.keys()
# Out:
# Parameter containing:
# tensor([[-0.0191, -0.0145, -0.0130,  ...,  0.0179, -0.0653, -0.1022],
#         [-0.0649, -0.0674, -0.0473,  ..., -0.0198,  0.0296, -0.0329],
#         [ 0.0637, -0.0933, -0.0536,  ..., -0.0213, -0.0408,  0.0238],
#         ...,
#         [-0.0507,  0.0713, -0.0390,  ..., -0.0244,  0.0218,  0.0387],
#         [ 0.1066, -0.0762, -0.0597,  ..., -0.0664,  0.0372, -0.0195],
#         [-0.0205,  0.0837, -0.0577,  ...,  0.0293,  0.0338,  0.0709]],
#        requires_grad=True)

# %%
numeric = embeddings_df_tsne.index.str.isnumeric()
color = np.where(numeric, "green", "black")
fig = go.Figure()

fig.add_trace(
    go.Scatter(
        x=embeddings_df_tsne[0],
        y=embeddings_df_tsne[1],
        mode="text",
        text=embeddings_df_tsne.index,
        textposition="middle center",
        textfont=dict(color=color),
    )
)
# fig.write_html("word2vec_visualization.html")
fig

# %%
# Compression to 64 dimensions
# t-SNE transform
# tsne_64 = TSNE(n_components=64, method="")
# emb_64 = tsne_64.fit_transform(embeddings_df)
# emb_64 = pd.DataFrame(emb_64)

# emb_64.index = vocab.keys()
# emb_64.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 4
#       1 # Compression to 64 dimensions
#       2 # t-SNE transform
#       3 tsne_64 = TSNE(n_components=64, method="exact")
# ----> 4 emb_64 = tsne_64.fit_transform(embeddings_df)
#       5 emb_64 = pd.DataFrame(emb_64)
#       7 emb_64.index = vocab.keys()
#
# File ~/Documents/Code/Simple Chatbot/.venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File ~/Documents/Code/Simple Chatbot/.venv/lib/python3.11/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/Code/Simple Chatbot/.venv/lib/python3.11/site-packages/sklearn/manifold/_t_sne.py:1136, in TSNE.fit_transform(self, X, y)
#    1115 """Fit X into an embedded space and return that transformed output.
#    1116
#    1117 Parameters
#    (...)
#    1133     Embedding of the training data in low-dimensional space.
#    1134 """
#    1135 self._check_params_vs_input(X)
# -> 1136 embedding = self._fit(X)
#    1137 self.embedding_ = embedding
#    1138 return self.embedding_
#
# File ~/Documents/Code/Simple Chatbot/.venv/lib/python3.11/site-packages/sklearn/manifold/_t_sne.py:1026, in TSNE._fit(self, X, skip_num_points)
#    1020 # Degrees of freedom of the Student's t-distribution. The suggestion
#    1021 # degrees_of_freedom = n_components - 1 comes from
#    1022 # "Learning a Parametric Embedding by Preserving Local Structure"
#    1023 # Laurens van der Maaten, 2009.
#    1024 degrees_of_freedom = max(self.n_components - 1, 1)
# -> 1026 return self._tsne(
#    1027     P,
#    1028     degrees_of_freedom,
#    1029     n_samples,
#    1030     X_embedded=X_embedded,
#    1031     neighbors=neighbors_nn,
#    1032     skip_num_points=skip_num_points,
#    1033 )
#
# File ~/Documents/Code/Simple Chatbot/.venv/lib/python3.11/site-packages/sklearn/manifold/_t_sne.py:1078, in TSNE._tsne(self, P, degrees_of_freedom, n_samples, X_embedded, neighbors, skip_num_points)
#    1075 # Learning schedule (part 1): do 250 iteration with lower momentum but
#    1076 # higher learning rate controlled via the early exaggeration parameter
#    1077 P *= self.early_exaggeration
# -> 1078 params, kl_divergence, it = _gradient_descent(obj_func, params, **opt_args)
#    1079 if self.verbose:
#    1080     print(
#    1081         "[t-SNE] KL divergence after %d iterations with early exaggeration: %f"
#    1082         % (it + 1, kl_divergence)
#    1083     )
#
# File ~/Documents/Code/Simple Chatbot/.venv/lib/python3.11/site-packages/sklearn/manifold/_t_sne.py:402, in _gradient_descent(objective, p0, it, n_iter, n_iter_check, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, verbose, args, kwargs)
#     399 # only compute the error when needed
#     400 kwargs["compute_error"] = check_convergence or i == n_iter - 1
# --> 402 error, grad = objective(p, *args, **kwargs)
#     404 inc = update * grad < 0.0
#     405 dec = np.invert(inc)
#
# File ~/Documents/Code/Simple Chatbot/.venv/lib/python3.11/site-packages/sklearn/manifold/_t_sne.py:199, in _kl_divergence(params, P, degrees_of_freedom, n_samples, n_components, skip_num_points, compute_error)
#     197 PQd = squareform((P - Q) * dist)
#     198 for i in range(skip_num_points, n_samples):
# --> 199     grad[i] = np.dot(np.ravel(PQd[i], order="K"), X_embedded[i] - X_embedded)
#     200 grad = grad.ravel()
#     201 c = 2.0 * (degrees_of_freedom + 1.0) / degrees_of_freedom
#
# KeyboardInterrupt:
