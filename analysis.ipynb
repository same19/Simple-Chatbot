# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchtext.datasets import WikiText2
import pandas as pd
from nltk.corpus import brown
import numpy as np
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import sys
from sklearn.manifold import TSNE
import plotly.graph_objects as go
import os

# %% [markdown]
# ## Analyze

# %%
from net import Net_CBOW

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
epoch_n = 5
version = "april30_WT2_nodatalim_20epoch_64dim_100minf_4window_epoch"
net = torch.load(f"saves/apr30epochs/model_{version}{epoch_n}.pt", map_location=device)
vocab = torch.load(f"saves/vocab_april30_WT2_nodatalim_20epoch_64dim_50minf_2window.pt")
# Out:
# cpu

# %%
# get first layer of the model
embeddings = list(net.parameters())[0]
embeddings = embeddings.cpu().detach().numpy()

# normalize the embeddings layer
norms = (embeddings ** 2).sum(axis=1) ** (0.5)
norms = np.reshape(norms, (len(norms), 1))
embeddings_norm = embeddings / norms
embeddings_norm.shape
embeddings_df = pd.DataFrame(embeddings)

# t-SNE transform
tsne = TSNE(n_components=2)
embeddings_df_tsne = tsne.fit_transform(embeddings_df)
embeddings_df_tsne = pd.DataFrame(embeddings_df_tsne)

embeddings_df_tsne.index = vocab.keys()

# %%
numeric = embeddings_df_tsne.index.str.isnumeric()
color = np.where(numeric, "green", "black")
fig = go.Figure()

fig.add_trace(
    go.Scatter(
        x=embeddings_df_tsne[0],
        y=embeddings_df_tsne[1],
        mode="text",
        text=embeddings_df_tsne.index,
        textposition="middle center",
        textfont=dict(color=color),
    )
)
# fig.write_html("word2vec_visualization.html")
fig

# %%
def lookup_id(word, vocab=vocab):
    if word not in vocab:
        return vocab["<unk>"]
    return vocab[word]
def lookup_token(word_id, vocab=vocab):
    for word in vocab:
        if vocab[word] == word_id:
            return word
    return None
def get_top_similar(word: str, topN: int = 10):
    if word not in vocab:
        print("Out of vocabulary word")
        return
    word_id = lookup_id(word)

    word_vec = embeddings_norm[word_id]
    word_vec = np.reshape(word_vec, (len(word_vec), 1))
    dists = np.matmul(embeddings_norm, word_vec).flatten()
    topN_ids = np.argsort(-dists)[1 : topN + 1]

    topN_dict = {}
    for sim_word_id in topN_ids:
        # sim_word = vocab.lookup_token(sim_word_id)
        sim_word = "<unk_>"
        for k in vocab:
            if vocab[k] == sim_word_id:
                sim_word = k
                break
        topN_dict[sim_word] = dists[sim_word_id]
    return topN_dict

# %%
for word, sim in get_top_similar("boy").items():
    print("{}: {:.3f}".format(word, sim))
# Out:
# everglades: 0.168
# 'malley: 0.164
# apf: 0.159
# short: 0.157
# flowers: 0.156
# substantially: 0.152
# mosque: 0.150
# cyrus: 0.148
# wrestling: 0.147
# narrow: 0.146

# %%
emb1 = embeddings[vocab["woman"]]
emb2 = embeddings[vocab["man"]]
emb3 = embeddings[vocab["girl"]]

emb4 = emb1 - emb2 + emb3
emb4_norm = (emb4 ** 2).sum() ** (1 / 2)
emb4 = emb4 / emb4_norm

emb4 = np.reshape(emb4, (len(emb4), 1))
dists = np.matmul(embeddings_norm, emb4).flatten()

top5 = np.argsort(-dists)[:5]

for word_id in top5:
    print("{}: {:.3f}".format(lookup_token(word_id), dists[word_id]))
# Out:
# girl: 0.636
# woman: 0.532
# catholics: 0.163
# 1898: 0.161
# caesar: 0.157

# %%
folder = "train_data/"
version1 = "_data_"
version2 = "_wt2_window4.pt"

# %%
x_test = torch.load(f"{folder}test{version1}x{version2}")
y_test = torch.load(f"{folder}test{version1}y{version2}")

# %%
x_test[0]
# Out:
# [629, 4, 22, 29, 108, 1, 392, 5]

# %%
lookup_token(y_test[1])
# Out:
# 'film'

# %%
[lookup_token(i) for i in x_test[3]]
# Out:
# ['an', 'english', 'film', ',', 'and', 'theatre', 'actor', '.']

# %%
vocab = torch.load("saves/vocab_may1_WT2_transformer_min25f.pt")
print(len(vocab))
def lookup_id(word, vocab=vocab):
    if word not in vocab:
        return vocab["<unk>"]
    return vocab[word]
def lookup_token(word_id, vocab=vocab):
    for word in vocab:
        if vocab[word] == word_id:
            return word
    return "<unk>"
# Out:
# 6908

# %%
from datasets import load_dataset
wikitext2 = load_dataset("wikitext", "wikitext-2-v1")
# text_train = wikitext2["train"]['text']
# text_train = [item.lower().strip() for item in text_train if len(item) > 0]
text_test = wikitext2["test"]['text']
text_test = [item.lower().strip() for item in text_test if len(item) > 0]
len(text_test)
# text_train = [item.split(" ") + ["\n"] for item in text_train if "=" not in item]
text_test = [item.split(" ") + ["\n"] for item in text_test if "=" not in item]

seq_length = 128
buffer = 20

x_test = [[lookup_id(word) for word in paragraph[len(paragraph)-seq_length-1:len(paragraph)-1]] for paragraph in text_test if len(paragraph) >= seq_length + buffer+1]

trytest = [lookup_token(i) for i in x_test[-1]]

# %%
from transformer import TransformerModel

# %%
# transformer = torch.load("saves/model_transformer_apr29_1130pm.pt")
# transformer = torch.load("saves/model_transformer_may1_1250pm.pt")
transformer = torch.load("saves/model_transformer_may2_0600pm.pt")
vocab = torch.load(f"saves/vocab_may1_WT2_transformer_min25f.pt")

# %%
def embed(word):    
    return transformer.input_emb(torch.tensor(lookup_id(word)))
cos = nn.CosineSimilarity(dim=0, eps=1e-6)
len(embed("mother"))
# Out:
# (512, 512)

# %%
device = torch.device("cpu")
ntokens = len(vocab)
input = torch.randint(ntokens, (1, 1), dtype=torch.long).to(device)
model = transformer
temperature = 2
log_interval = 1

input = 'he claimed in an interview that '
# input = ['<unk>', 'claimed', 'in', 'an', 'interview', 'at', 'the', 'time', 'of', 'the', 'film', "'s", 'release', 'that', 'the', 'character', 'of', 'minnesota', '<unk>', 'was', 'based', 'on', '<unk>', ',', 'who', 'at', 'the', 'time', 'was', 'known', 'as', '"', 'new', 'york', '<unk>', '"', '.', '<unk>', 'immediately', 'adopted', 'the', 'minnesota', '<unk>', '<unk>', 'and', '<unk>', 'his', 'association', 'with', 'the', 'film', 'into', 'book', 'and', 'television', '<unk>', 'and', 'other', '<unk>', '.', 'author', 'walter', '<unk>', 'denied', 'for', 'the', 'rest', 'of', 'his', 'life', 'that', '<unk>', 'had', 'played', 'any', 'role', 'in', 'the', 'creation', 'of', 'the', 'character', '.', 'other', 'players', 'would', 'claim', ',', 'with', 'greater', 'or', '<unk>', 'degrees', 'of', '<unk>', ',', 'to', 'have', 'served', 'as']
input = [lookup_id(i) for i in input.strip().split(" ")]
# input = [lookup_id(i) for i in input]


print(input)
input = torch.tensor(input).view(len(input), 1)


with open('out_generation.txt', 'w') as outf:
    with torch.no_grad():  # no tracking history
        for i in range(100):
            print(i)
            output = model(input, False)
            word_weights = output[-1].squeeze().div(temperature).exp().cpu()
            word_idx = torch.multinomial(word_weights, 1)[0]
            word_tensor = torch.Tensor([[word_idx]]).long().to(device)
            print(word_tensor)
            input = torch.cat([input, word_tensor], 0)

            word = lookup_token(word_idx)

            outf.write(word + ('\n' if i % 20 == 19 else ' '))

            if i % log_interval == 0:
                print('| Generated {}/{} words'.format(i, [lookup_token(i[0])for i in input]))
# Out:
# [27, 760, 6, 29, 1128, 15]
# 0
# tensor([[82]])
# | Generated 0/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there'] words
# 1
# tensor([[5028]])
# | Generated 1/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep'] words
# 2
# tensor([[5803]])
# | Generated 2/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished'] words
# 3
# tensor([[2909]])
# | Generated 3/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric'] words
# 4
# tensor([[4527]])
# | Generated 4/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation'] words
# 5
# tensor([[163]])
# | Generated 5/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did'] words
# 6
# tensor([[1]])
# | Generated 6/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ','] words
# 7
# tensor([[4033]])
# | Generated 7/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping'] words
# 8
# tensor([[2804]])
# | Generated 8/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency'] words
# 9
# tensor([[5283]])
# | Generated 9/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged'] words
# 10
# tensor([[3871]])
# | Generated 10/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil'] words
# 11
# tensor([[2058]])
# | Generated 11/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment'] words
# 12
# tensor([[2147]])
# | Generated 12/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages'] words
# 13
# tensor([[68]])
# | Generated 13/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over'] words
# 14
# tensor([[3]])
# | Generated 14/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of'] words
# 15
# tensor([[4406]])
# | Generated 15/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic'] words
# 16
# tensor([[669]])
# | Generated 16/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops'] words
# 17
# tensor([[2331]])
# | Generated 17/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened'] words
# 18
# tensor([[568]])
# | Generated 18/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared'] words
# 19
# tensor([[4796]])
# | Generated 19/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized'] words
# 20
# tensor([[271]])
# | Generated 20/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old'] words
# 21
# tensor([[4764]])
# | Generated 21/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate'] words
# 22
# tensor([[5312]])
# | Generated 22/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement'] words
# 23
# tensor([[191]])
# | Generated 23/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off'] words
# 24
# tensor([[4085]])
# | Generated 24/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff'] words
# 25
# tensor([[5419]])
# | Generated 25/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff', 'devotion'] words
# 26
# tensor([[3234]])
# | Generated 26/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff', 'devotion', 'difficulties'] words
# 27
# tensor([[426]])
# | Generated 27/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff', 'devotion', 'difficulties', 'instead'] words
# 28
# tensor([[5744]])
# | Generated 28/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff', 'devotion', 'difficulties', 'instead', 'qualifying'] words
# 29
# tensor([[38]])
# | Generated 29/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff', 'devotion', 'difficulties', 'instead', 'qualifying', 'first'] words
# 30
# tensor([[1104]])
# | Generated 30/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff', 'devotion', 'difficulties', 'instead', 'qualifying', 'first', 'tons'] words
# 31
# tensor([[1746]])
# | Generated 31/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff', 'devotion', 'difficulties', 'instead', 'qualifying', 'first', 'tons', 'knowledge'] words
# 32
# tensor([[4787]])
# | Generated 32/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff', 'devotion', 'difficulties', 'instead', 'qualifying', 'first', 'tons', 'knowledge', 'presents'] words
# 33
# tensor([[2568]])
# | Generated 33/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff', 'devotion', 'difficulties', 'instead', 'qualifying', 'first', 'tons', 'knowledge', 'presents', 'montana'] words
# 34
# tensor([[2624]])
# | Generated 34/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff', 'devotion', 'difficulties', 'instead', 'qualifying', 'first', 'tons', 'knowledge', 'presents', 'montana', 'introduction'] words
# 35
# tensor([[6861]])
# | Generated 35/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff', 'devotion', 'difficulties', 'instead', 'qualifying', 'first', 'tons', 'knowledge', 'presents', 'montana', 'introduction', 'scales'] words
# 36
# tensor([[2933]])
# | Generated 36/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff', 'devotion', 'difficulties', 'instead', 'qualifying', 'first', 'tons', 'knowledge', 'presents', 'montana', 'introduction', 'scales', 'dream'] words
# 37
# tensor([[4290]])
# | Generated 37/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff', 'devotion', 'difficulties', 'instead', 'qualifying', 'first', 'tons', 'knowledge', 'presents', 'montana', 'introduction', 'scales', 'dream', '”'] words
# 38
# tensor([[4583]])
# | Generated 38/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff', 'devotion', 'difficulties', 'instead', 'qualifying', 'first', 'tons', 'knowledge', 'presents', 'montana', 'introduction', 'scales', 'dream', '”', 'e
['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff', 'devotion', 'difficulties', 'instead', 'qualifying', 'first', 'tons', 'knowledge', 'presents', 'montana', 'introduction', 'scales', 'dream', '”', 'eve', 'star', 'as', 'armies', 'provided', 'parties', 'indoor', 'came', 'doofenshmirtz', 'moving', '350', 'matches', 'deployed', 'ashore', ',', 'year', 'semi', '"', '0', 'early', 'expedition', 'inland', 'only', 'fed', 'control', 'crosses', ';', 'it', 'angelou', 'shows', 'last', 'fee', 'including', 'several', 'ice', 'find', 'them', 'goes', 'war', ',', 'when', 'stock', 'number', 'things', 'go', 'out', 'chelsea', 'required', 'right', 'kept', 'ulysses', 'shortly', 'happen', 'engines', 'drove'] words
# 93
# tensor([[2432]])
# | Generated 93/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff', 'devotion', 'difficulties', 'instead', 'qualifying', 'first', 'tons', 'knowledge', 'presents', 'montana', 'introduction', 'scales', 'dream', '”', 'eve', 'star', 'as', 'armies', 'provided', 'parties', 'indoor', 'came', 'doofenshmirtz', 'moving', '350', 'matches', 'deployed', 'ashore', ',', 'year', 'semi', '"', '0', 'early', 'expedition', 'inland', 'only', 'fed', 'control', 'crosses', ';', 'it', 'angelou', 'shows', 'last', 'fee', 'including', 'several', 'ice', 'find', 'them', 'goes', 'war', ',', 'when', 'stock', 'number', 'things', 'go', 'out', 'chelsea', 'required', 'right', 'kept', 'ulysses', 'shortly', 'happen', 'engines', 'drove', 'flights'] words
# 94
# tensor([[2908]])
# | Generated 94/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff', 'devotion', 'difficulties', 'instead', 'qualifying', 'first', 'tons', 'knowledge', 'presents', 'montana', 'introduction', 'scales', 'dream', '”', 'eve', 'star', 'as', 'armies', 'provided', 'parties', 'indoor', 'came', 'doofenshmirtz', 'moving', '350', 'matches', 'deployed', 'ashore', ',', 'year', 'semi', '"', '0', 'early', 'expedition', 'inland', 'only', 'fed', 'control', 'crosses', ';', 'it', 'angelou', 'shows', 'last', 'fee', 'including', 'several', 'ice', 'find', 'them', 'goes', 'war', ',', 'when', 'stock', 'number', 'things', 'go', 'out', 'chelsea', 'required', 'right', 'kept', 'ulysses', 'shortly', 'happen', 'engines', 'drove', 'flights', 'talk'] words
# 95
# tensor([[47]])
# | Generated 95/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff', 'devotion', 'difficulties', 'instead', 'qualifying', 'first', 'tons', 'knowledge', 'presents', 'montana', 'introduction', 'scales', 'dream', '”', 'eve', 'star', 'as', 'armies', 'provided', 'parties', 'indoor', 'came', 'doofenshmirtz', 'moving', '350', 'matches', 'deployed', 'ashore', ',', 'year', 'semi', '"', '0', 'early', 'expedition', 'inland', 'only', 'fed', 'control', 'crosses', ';', 'it', 'angelou', 'shows', 'last', 'fee', 'including', 'several', 'ice', 'find', 'them', 'goes', 'war', ',', 'when', 'stock', 'number', 'things', 'go', 'out', 'chelsea', 'required', 'right', 'kept', 'ulysses', 'shortly', 'happen', 'engines', 'drove', 'flights', 'talk', 'her'] words
# 96
# tensor([[79]])
# | Generated 96/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff', 'devotion', 'difficulties', 'instead', 'qualifying', 'first', 'tons', 'knowledge', 'presents', 'montana', 'introduction', 'scales', 'dream', '”', 'eve', 'star', 'as', 'armies', 'provided', 'parties', 'indoor', 'came', 'doofenshmirtz', 'moving', '350', 'matches', 'deployed', 'ashore', ',', 'year', 'semi', '"', '0', 'early', 'expedition', 'inland', 'only', 'fed', 'control', 'crosses', ';', 'it', 'angelou', 'shows', 'last', 'fee', 'including', 'several', 'ice', 'find', 'them', 'goes', 'war', ',', 'when', 'stock', 'number', 'things', 'go', 'out', 'chelsea', 'required', 'right', 'kept', 'ulysses', 'shortly', 'happen', 'engines', 'drove', 'flights', 'talk', 'her', 'may'] words
# 97
# tensor([[867]])
# | Generated 97/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff', 'devotion', 'difficulties', 'instead', 'qualifying', 'first', 'tons', 'knowledge', 'presents', 'montana', 'introduction', 'scales', 'dream', '”', 'eve', 'star', 'as', 'armies', 'provided', 'parties', 'indoor', 'came', 'doofenshmirtz', 'moving', '350', 'matches', 'deployed', 'ashore', ',', 'year', 'semi', '"', '0', 'early', 'expedition', 'inland', 'only', 'fed', 'control', 'crosses', ';', 'it', 'angelou', 'shows', 'last', 'fee', 'including', 'several', 'ice', 'find', 'them', 'goes', 'war', ',', 'when', 'stock', 'number', 'things', 'go', 'out', 'chelsea', 'required', 'right', 'kept', 'ulysses', 'shortly', 'happen', 'engines', 'drove', 'flights', 'talk', 'her', 'may', 'forward'] words
# 98
# tensor([[2]])
# | Generated 98/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff', 'devotion', 'difficulties', 'instead', 'qualifying', 'first', 'tons', 'knowledge', 'presents', 'montana', 'introduction', 'scales', 'dream', '”', 'eve', 'star', 'as', 'armies', 'provided', 'parties', 'indoor', 'came', 'doofenshmirtz', 'moving', '350', 'matches', 'deployed', 'ashore', ',', 'year', 'semi', '"', '0', 'early', 'expedition', 'inland', 'only', 'fed', 'control', 'crosses', ';', 'it', 'angelou', 'shows', 'last', 'fee', 'including', 'several', 'ice', 'find', 'them', 'goes', 'war', ',', 'when', 'stock', 'number', 'things', 'go', 'out', 'chelsea', 'required', 'right', 'kept', 'ulysses', 'shortly', 'happen', 'engines', 'drove', 'flights', 'talk', 'her', 'may', 'forward', '.'] words
# 99
# tensor([[600]])
# | Generated 99/['he', 'claimed', 'in', 'an', 'interview', 'that', 'there', 'sleep', 'accomplished', 'electric', 'cooperation', 'did', ',', 'keeping', 'agency', 'urged', 'brazil', 'treatment', 'stages', 'over', 'of', 'logic', 'troops', 'weakened', 'appeared', 'authorized', 'old', 'appropriate', 'improvement', 'off', 'geoff', 'devotion', 'difficulties', 'instead', 'qualifying', 'first', 'tons', 'knowledge', 'presents', 'montana', 'introduction', 'scales', 'dream', '”', 'eve', 'star', 'as', 'armies', 'provided', 'parties', 'indoor', 'came', 'doofenshmirtz', 'moving', '350', 'matches', 'deployed', 'ashore', ',', 'year', 'semi', '"', '0', 'early', 'expedition', 'inland', 'only', 'fed', 'control', 'crosses', ';', 'it', 'angelou', 'shows', 'last', 'fee', 'including', 'several', 'ice', 'find', 'them', 'goes', 'war', ',', 'when', 'stock', 'number', 'things', 'go', 'out', 'chelsea', 'required', 'right', 'kept', 'ulysses', 'shortly', 'happen', 'engines', 'drove', 'flights', 'talk', 'her', 'may', 'forward', '.', 'close'] words

# %%
# get first layer of the model
embeddings = list(transformer.input_emb.parameters())[0]
print(embeddings)
embeddings = embeddings.cpu().detach().numpy()

# normalize the embeddings layer
norms = (embeddings ** 2).sum(axis=1) ** (0.5)
norms = np.reshape(norms, (len(norms), 1))
embeddings_norm = embeddings / norms
embeddings_norm.shape
embeddings_df = pd.DataFrame(embeddings)

# t-SNE transform
tsne = TSNE(n_components=2)
embeddings_df_tsne = tsne.fit_transform(embeddings_df)
embeddings_df_tsne = pd.DataFrame(embeddings_df_tsne)

embeddings_df_tsne.index = vocab.keys()
# Out:
# Parameter containing:
# tensor([[-0.0223, -0.0210, -0.0084,  ...,  0.0260, -0.0721, -0.1039],
#         [-0.0706, -0.0780, -0.0480,  ..., -0.0224,  0.0223, -0.0369],
#         [ 0.0678, -0.0957, -0.0461,  ..., -0.0223, -0.0412,  0.0380],
#         ...,
#         [-0.0531,  0.0675, -0.0308,  ..., -0.0200,  0.0172,  0.0278],
#         [ 0.0941, -0.0779, -0.0542,  ..., -0.0703,  0.0469, -0.0180],
#         [-0.0240,  0.0837, -0.0550,  ...,  0.0270,  0.0387,  0.0668]],
#        requires_grad=True)

# %%
numeric = embeddings_df_tsne.index.str.isnumeric()
color = np.where(numeric, "green", "black")
fig = go.Figure()

fig.add_trace(
    go.Scatter(
        x=embeddings_df_tsne[0],
        y=embeddings_df_tsne[1],
        mode="text",
        text=embeddings_df_tsne.index,
        textposition="middle center",
        textfont=dict(color=color),
    )
)
# fig.write_html("word2vec_visualization.html")
fig
